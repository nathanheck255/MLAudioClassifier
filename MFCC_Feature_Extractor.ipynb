# %% [markdown]
# <h1> MFCC Feature Extractor </h1>
# <p> This is stage 1 of the Method 1 pipeline, so this should be the first notebook you run after unzipping the data archives. </p>

# %%
# Load libraries
import numpy as np
from math import log, pi, exp, ceil
import statistics as st
import pandas as pd
import scipy.io as io
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
import librosa
import librosa.display
import glob
import os
import json

# %%
# please set this variable to where you cloned the git repo "final-project-code-nathanheck255"

filepath = "/blue/eel6825/nathan.heck/FinalProject/final-project-code-nathanheck255"
os.chdir(filepath)

# make sure you have extracted the Training and Testing Data before you proceed with the rest of the notebook
# with something like "unzip TrainingData.zip"
#

# %% [markdown]
# <h1> Loading training data </h1>
# <p> This block of code will load in each audio file of the training data set and calculate it's MFCCs. Please note that there will be a lot of warnings in red after you run this cell, but they are just warnings and the code is still running fine without errors. </p>

# %%
os.chdir("TrainingData/AudioSamples")
folder_names = glob.glob("*")
all_samples = { 'label':[], 'mfcc':[] }
i=0
frames_max = 0
for instrument in folder_names:
    os.chdir(instrument)
    file_names = glob.glob("*.wav")
    for wav in file_names:
        waveform, samplerate = librosa.load(wav, sr=44100, mono=True)
        waveform = librosa.util.fix_length(waveform, size=50000)
        mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
        normalized_mfcc = librosa.util.normalize(mfcc)
        all_samples['mfcc'].append(normalized_mfcc.tolist())
        all_samples['label'].append(i)
        # Update frames maximum
        #if (num_frames > frames_max):
            #frames_max = num_frames
    os.chdir("..")
    i=i+1
os.chdir(filepath)
# Out:
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[1.3363361e-04 1.4913082e-04 4.0769577e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-1.3995171e-04  9.6440315e-05 -3.0505657e-04 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[ 0.         -0.00023079  0.00095129 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-6.5207481e-05  1.5807152e-04 -1.1360645e-04 ... -2.2959709e-04
#  -3.9446354e-04 -2.8848648e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[ 1.8674135e-04 -1.6450882e-04 -9.4294548e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-0.00503492  0.02644813 -0.01940799 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[4.5657158e-05 1.1187792e-04 1.8537045e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-3.0457973e-05 -3.0457973e-05 -3.0457973e-05 ...  5.9604645e-08
#   5.9604645e-08  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-0.00220239 -0.00734949 -0.00374675 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[ 0.0000000e+00 -4.7683716e-07  1.4543533e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[0.         0.00018382 0.00036675 ... 0.00364035 0.00816721 0.00940019] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-0.00616932 -0.0019747  -0.006235   ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[ 1.21593475e-04 -3.29017639e-05  1.67369843e-04 ... -1.42574310e-04
#  -1.32322311e-05 -3.05175781e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-0.00119114 -0.00238121 -0.00119078 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[ 0.0000000e+00 -7.1823597e-05  1.8882751e-04 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[ 2.9206276e-06  1.5246868e-04 -5.3346157e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-8.4161758e-05 -2.2172928e-05 -6.2823296e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[0.00076926 0.00054133 0.00339723 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[ 0.0000000e+00  2.4616718e-05 -7.5340271e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-0.00378239  0.0022738   0.01533067 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-0.00212193  0.00061905  0.0056057  ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[ 1.3774633e-04 -6.1750412e-05  2.8818846e-04 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-2.8991699e-04 -2.7453899e-04 -1.9830465e-04 ...  5.9604645e-08
#   1.0681152e-04  5.6463480e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-0.59301126  0.04163051  0.50095546 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[
000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[ 0.         -0.00013536 -0.00057012 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[0.00167811 0.00290346 0.00032485 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[0.00210738 0.00206721 0.00205386 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-5.8287382e-04 -5.1385164e-04 -4.0495396e-04 ...  7.3850155e-05
#   7.0035458e-05  7.3790550e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-3.1281710e-03 -5.8189034e-03 -9.0876818e-03 ... -2.4735928e-05
#  -2.3722649e-05 -2.8192997e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[0.00112474 0.00111496 0.00111699 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-3.1191111e-04 -5.3411722e-04 -8.9377165e-04 ...  1.6093254e-06
#   4.2319298e-06 -1.0728836e-06] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-0.0027771  -0.00278223 -0.00293779 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[ 6.1154366e-05 -3.0457973e-05 -1.5139580e-05 ... -3.0398369e-05
#  -1.8310547e-04 -1.3726950e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[ 0.0000000e+00 -1.1920929e-07 -1.1920929e-07 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/3799604476.py:13: FutureWarning: Pass y=[-0.00210488 -0.00179178 -0.00132769 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)

# %% [markdown]
# <h1> Loading testing data </h1>
# <p> This block of code will load in each audio file of the testing data set and calculate it's MFCCs. Please note that there will be a lot of warnings in red after you run this cell, but they are just warnings and the code is still running fine without errors. </p>

# %%
os.chdir(filepath)
os.chdir("TestData/TestData")
folder_names = glob.glob("*")
test_samples = { 'label':[], 'mfcc':[] }
i=0
frames_max = 0
for instrument in folder_names:
    os.chdir(instrument)
    file_names = glob.glob("*.wav")
    for wav in file_names:
        waveform, samplerate = librosa.load(wav, sr=44100, mono=True)
        waveform = librosa.util.fix_length(waveform, size=50000)
        mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
        normalized_mfcc = librosa.util.normalize(mfcc)
        test_samples['mfcc'].append(normalized_mfcc.tolist())
        test_samples['label'].append(i)
        # Update frames maximum
        #if (num_frames > frames_max):
            #frames_max = num_frames
    os.chdir("..")
    i=i+1
os.chdir("../..")
# Out:
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[-0.00026166  0.00038475  0.00068074 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[ 0.04202372  0.06057823  0.07214892 ... -0.00108683  0.0003649
#   0.00295538] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[ 1.7940998e-05 -2.9861927e-05  3.2722950e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[-1.13427639e-04 -9.48905945e-05 -1.04904175e-05 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[ 0.00110233 -0.01973426 -0.01444936 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[-0.04662436  0.33776325  0.2007041  ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[ 0.00137997 -0.00205106 -0.00836968 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[-0.00010186 -0.00013477  0.00016272 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[-0.04662436  0.33776325  0.2007041  ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[-5.1081181e-05  2.9325485e-05  6.4373016e-06 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[ 0.08177358  0.08144432 -0.02213794 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[-6.9797039e-05 -1.2570620e-04 -1.8286705e-04 ... -6.5326691e-05
#  -3.5166740e-05 -9.6440315e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[-0.00020868 -0.00020659 -0.00020999 ...  0.00251663  0.002478
#   0.00148678] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[ 0.05205953 -0.22085524 -0.38897324 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[ 3.0219555e-05 -4.0650368e-05  6.4790249e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[ 0.12520707  0.11103839  0.00803143 ...  0.00118089 -0.00225556
#  -0.00516021] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[-1.3619661e-04  6.0081482e-05 -1.4781952e-04 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[-4.9114227e-05 -9.3400478e-05 -7.5638294e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc=librosa.feature.mfcc(waveform, n_mfcc=40, n_fft=2048, hop_length=512)
# /scratch/local/62450859/ipykernel_39096/1345291590.py:13: FutureWarning: Pass y=[