# %%
import os
import numpy as np
from pathlib import Path
from PIL import Image
from tqdm import tqdm
import matplotlib
from matplotlib import pyplot as plt

import glob
from sklearn.model_selection import train_test_split
import librosa
import librosa.display
import json

import pickle


import keras
from keras import layers
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Dense, Lambda, Flatten, Reshape
from keras.models import Model
from keras import backend as K
from keras.callbacks import TensorBoard

import cv2

from keras.optimizers import Adam

# %%
os.chdir("/blue/eel6825/nathan.heck/FinalProject/AudioSamples")
folder_names = glob.glob("*")
x_train = []
t_train = []
i=0
for instrument in folder_names:
    os.chdir(instrument)
    file_names = glob.glob("*.wav")
    for wav in file_names:
        waveform, samplerate = librosa.load(wav, sr=22050, mono=True)
        waveform = librosa.util.fix_length(waveform, size=32600)
        spec = librosa.feature.melspectrogram(y=waveform, sr=samplerate, n_fft = 512, hop_length = 256)
        normalized_spec = librosa.util.normalize(spec)
        x_train.append(normalized_spec)
        t_train.append(i)
        #np.save("/blue/eel6825/nathan.heck/FinalProject/Spectrograms/"+wav, normalized_spec)
    os.chdir("..")
    i=i+1
    
    
    
x_train = np.array(x_train)
x_train = x_train[..., np.newaxis]

os.chdir("/blue/eel6825/nathan.heck/FinalProject/")

# %%
kick_plot = np.load("/blue/eel6825/nathan.heck/FinalProject/Spectrograms/80s Digital Kick 01.wav.npy")
print(kick_plot.shape)
plt.figure()
plt.imshow(kick_plot)

snare_plot = np.load("/blue/eel6825/nathan.heck/FinalProject/Spectrograms/Acoustic Snare 01.wav.npy")
print(snare_plot.shape)
plt.figure()
plt.imshow(snare_plot)

hihat_plot = np.load("/blue/eel6825/nathan.heck/FinalProject/Spectrograms/Acoustic Closed Hat 01.wav.npy")
print(hihat_plot.shape)
plt.figure()
plt.imshow(hihat_plot)
# Out:
# (128, 128)
# (128, 128)
# (128, 128)

# %%
input_img = keras.Input(shape=(128, 128, 1))

###
# Define the encoder of an autoencoder. 
# It should take in the 'input_img' variable, and output the encoded input, with a chosen number of dimensions
# Define multiple sets of {convolutional, maxpooling} layers.
# YOUR CODE BELOW

#encoded
x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)
#
###


###
# Define the decoder of our autoencoder. 
# It should take in the 'encoded' variable, and output the decoded input, here the same dimensions as the input (128, 128, 1).
# Define multiple sets of {convolutional, upsampling} layers.
# YOUR CODE BELOW
x = Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu',padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='relu', padding='same')(x)

#
###

autoencoder = keras.Model(input_img, decoded)

# Feel free to play around with the learning rate.
opt = Adam(learning_rate=1e-3)
autoencoder.compile(loss="mse", optimizer=opt)

# %%
print(x_train.shape)
autoencoder.fit(x_train, x_train,
               epochs=1,
               batch_size=128,
               shuffle=True,
               callbacks=[TensorBoard(log_dir="logs")])
# Out:
# (918, 128, 128, 1)
# 8/8 [==============================] - 15s 2s/step - loss: 0.0083

# %%
encoder=keras.Model(input_img, encoded)
encoder_output = encoder.predict(x_train)
# Out:
# 29/29 [==============================] - 2s 61ms/step

# %%
latents = np.reshape(encoder_output, [918, 16*16*8])
print(latents.shape)
plt.figure(figsize=(6, 6))
plt.scatter(latents[:, 0], latents[:, 1], c=t_train)
plt.colorbar()
plt.show()
# Out:
# (918, 2048)

# %%
t = np.array(t_train)

X_train, X_val, y_train, y_val = train_test_split(encoder_output, t, test_size=0.2, stratify=t)

# Neural network
model = keras.Sequential([

        # input layer
        keras.layers.Flatten(input_shape=(encoder_output.shape[1], encoder_output.shape[2], encoder_output.shape[3])),

        # 1st dense layer
        keras.layers.Dense(512, activation='relu'),

        # 2nd dense layer
        keras.layers.Dense(256, activation='relu'),

        # 3rd dense layer
        keras.layers.Dense(64, activation='relu'),

        # output layer
        keras.layers.Dense(3, activation='softmax')
])
    
optimiser = keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 512)               1049088
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dense_6 (Dense)             (None, 64)                16448
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 1,197,059
# Trainable params: 1,197,059
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=32, epochs=30)
os.chdir("/blue/eel6825/nathan.heck/FinalProject/")
model.save('model2.h5')
# Out:
# Epoch 1/30
# 23/23 [==============================] - 0s 11ms/step - loss: 1.0130 - accuracy: 0.5954 - val_loss: 0.8956 - val_accuracy: 0.6957
# Epoch 2/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.7975 - accuracy: 0.6839 - val_loss: 0.6664 - val_accuracy: 0.7011
# Epoch 3/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5979 - accuracy: 0.7779 - val_loss: 0.4931 - val_accuracy: 0.9130
# Epoch 4/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4510 - accuracy: 0.8937 - val_loss: 0.3765 - val_accuracy: 0.9293
# Epoch 5/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3467 - accuracy: 0.9183 - val_loss: 0.3019 - val_accuracy: 0.9348
# Epoch 6/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2737 - accuracy: 0.9196 - val_loss: 0.2532 - val_accuracy: 0.9402
# Epoch 7/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2182 - accuracy: 0.9346 - val_loss: 0.2245 - val_accuracy: 0.9348
# Epoch 8/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1804 - accuracy: 0.9428 - val_loss: 0.2087 - val_accuracy: 0.9348
# Epoch 9/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.1548 - accuracy: 0.9496 - val_loss: 0.2004 - val_accuracy: 0.9402
# Epoch 10/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1354 - accuracy: 0.9550 - val_loss: 0.1960 - val_accuracy: 0.9348
# Epoch 11/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1200 - accuracy: 0.9578 - val_loss: 0.1906 - val_accuracy: 0.9457
# Epoch 12/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1063 - accuracy: 0.9619 - val_loss: 0.1949 - val_accuracy: 0.9293
# Epoch 13/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0948 - accuracy: 0.9700 - val_loss: 0.1876 - val_accuracy: 0.9457
# Epoch 14/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0865 - accuracy: 0.9728 - val_loss: 0.1796 - val_accuracy: 0.9511
# Epoch 15/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0775 - accuracy: 0.9728 - val_loss: 0.1796 - val_accuracy: 0.9402
# Epoch 16/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0703 - accuracy: 0.9796 - val_loss: 0.1845 - val_accuracy: 0.9457
# Epoch 17/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0655 - accuracy: 0.9796 - val_loss: 0.1753 - val_accuracy: 0.9402
# Epoch 18/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0594 - accuracy: 0.9850 - val_loss: 0.1813 - val_accuracy: 0.9402
# Epoch 19/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0558 - accuracy: 0.9823 - val_loss: 0.1680 - val_accuracy: 0.9565
# Epoch 20/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0514 - accuracy: 0.9837 - val_loss: 0.1762 - val_accuracy: 0.9402
# Epoch 21/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0466 - accuracy: 0.9837 - val_loss: 0.1706 - val_accuracy: 0.9457
# Epoch 22/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0435 - accuracy: 0.9877 - val_loss: 0.1719 - val_accuracy: 0.9511
# Epoch 23/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0406 - accuracy: 0.9877 - val_loss: 0.1778 - val_accuracy: 0.9457
# Epoch 24/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0371 - accuracy: 0.9891 - val_loss: 0.1680 - val_accuracy: 0.9565
# Epoch 25/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0345 - accuracy: 0.9918 - val_loss: 0.1728 - val_accuracy: 0.9511
# Epoch 26/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0336 - accuracy: 0.9891 - val_loss: 0.1659 - val_accuracy: 0.9565
# Epoch 27/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0316 - accuracy: 0.9905 - val_loss: 0.1701 - val_accuracy: 0.9511
# Epoch 28/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0285 - accuracy: 0.9905 - val_loss: 0.1682 - val_accuracy: 0.9457
# Epoch 29/30
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0265 - accuracy: 0.9932 - val_loss: 0.1686 - val_accuracy: 0.9511
# Epoch 30/30
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0249 - accuracy: 0.9946 - val_loss: 0.1662 - val_accuracy: 0.9620

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('accuracy.png')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('loss.png')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
os.chdir("/blue/eel6825/nathan.heck/FinalProject/")
os.chdir("TestData")
folder_names = glob.glob("*")
x_test = []
t_test = []
i=0
for instrument in folder_names:
    os.chdir(instrument)
    file_names = glob.glob("*.wav")
    for wav in file_names:
        waveform, samplerate = librosa.load(wav, sr=22050, mono=True)
        waveform = librosa.util.fix_length(waveform, size=32600)
        spec = librosa.feature.melspectrogram(y=waveform, sr=samplerate, n_fft = 512, hop_length = 256)
        normalized_spec = librosa.util.normalize(spec)
        x_test.append(normalized_spec)
        t_test.append(i)
    os.chdir("..")
    i=i+1
    
    
    
x_test = np.array(x_test)
x_test = x_test[..., np.newaxis]

os.chdir("/blue/eel6825/nathan.heck/FinalProject/")

# %%
encoder_test_output = encoder.predict(x_test)
# Out:
# 2/2 [==============================] - 0s 23ms/step

# %%
yhat = model.predict(encoder_test_output)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(t_test,yhat.argmax(axis=1))
print(cm)
# Out:
# [[19  1  0]
#  [ 0 14  0]
#  [ 0  0  9]]

# %%
print(len(t_test))
# Out:
# 43
